# %% [markdown]
# # UNet — Tissue Segmentation — Colab Runner

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %pip install -q tifffile shapely opencv-python matplotlib numpy torch torchvision pillow tqdm wandb

# %%
import wandb
wandb.login()

# %%
import subprocess, sys
from pathlib import Path

UNET = Path('/content/drive/MyDrive/cv-assignment/histopathology-cv/1a_unet')

# Edit run.py to set your desired RUN_NAME / config before running
subprocess.run([sys.executable, str(UNET / 'run.py'), 'both'], check=True, cwd=str(UNET))
